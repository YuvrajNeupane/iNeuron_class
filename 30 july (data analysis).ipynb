# %%
import pandas as pd

# %%
df=pd.read_csv('D:\s\iNuron\data\sales_data_final.csv')

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
round(df.describe(),2)
# Out:
#        quantity  discount    profit  shipping_cost      year
# count  51290.00  51290.00  51290.00       51290.00  51290.00
# mean       3.48      0.14     28.64          26.38   2012.78
# std        2.28      0.21    174.42          57.30      1.10
# min        1.00      0.00  -6599.98           0.00   2011.00
# 25%        2.00      0.00      0.00           2.61   2012.00
# 50%        3.00      0.00      9.24           7.79   2013.00
# 75%        5.00      0.20     36.81          24.45   2014.00
# max       14.00      0.85   8399.98         933.57   2014.00

# %%
df[['profit']]
# Out:
#          profit
# 0      106.1400
# 1       36.0360
# 2       29.6400
# 3      -26.0550
# 4       37.7700
# ...         ...
# 51285    4.5188
# 51286    0.4200
# 51287   12.3600
# 51288    0.5600
# 51289   -0.6048
#
# [51290 rows x 1 columns]

# %%
df.isnull().sum()
# Out:
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_name     0
# segment           0
# state             0
# country           0
# market            0
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales             0
# quantity          0
# discount          0
# profit            0
# shipping_cost     0
# order_priority    0
# year              0
# dtype: int64

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
df.dtypes == 'object'
# Out:
# order_id           True
# order_date         True
# ship_date          True
# ship_mode          True
# customer_name      True
# segment            True
# state              True
# country            True
# market             True
# region             True
# product_id         True
# category           True
# sub_category       True
# product_name       True
# sales              True
# quantity          False
# discount          False
# profit            False
# shipping_cost     False
# order_priority     True
# year              False
# dtype: bool

# %%
df[df.dtypes[df.dtypes == 'object'].index]
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
type(d)
# Out:
# pandas.core.series.Series

# %%
df[df.dtypes[df.dtypes == 'object'].index].describe()
# Out:
#               order_id order_date   ship_date       ship_mode  \
# count            51290      51290       51290           51290
# unique           25035       1430        1464               4
# top     CA-2014-100111  6/18/2014  11/22/2014  Standard Class
# freq                14        135         130           30775
#
#           customer_name   segment       state        country market   region  \
# count             51290     51290       51290          51290  51290    51290
# unique              795         3        1094            147      7       13
# top     Muhammed Yedwab  Consumer  California  United States   APAC  Central
# freq                108     26518        2001           9994  11002    11117
#
#              product_id         category sub_category product_name  sales  \
# count             51290            51290        51290        51290  51290
# unique            10292                3           17         3788   2246
# ...

# %%
df.dtypes == 'float'
# Out:
# order_id          False
# order_date        False
# ship_date         False
# ship_mode         False
# customer_name     False
# segment           False
# state             False
# country           False
# market            False
# region            False
# product_id        False
# category          False
# sub_category      False
# product_name      False
# sales             False
# quantity          False
# discount           True
# profit             True
# shipping_cost      True
# order_priority    False
# year              False
# dtype: bool

# %%
df[df.dtypes[df.dtypes == 'float64'].index]
# Out:
#        discount    profit  shipping_cost
# 0           0.0  106.1400          35.46
# 1           0.1   36.0360           9.72
# 2           0.0   29.6400           8.17
# 3           0.5  -26.0550           4.82
# 4           0.1   37.7700           4.70
# ...         ...       ...            ...
# 51285       0.2    4.5188           0.89
# 51286       0.0    0.4200           0.49
# 51287       0.0   12.3600           0.35
# 51288       0.0    0.5600           0.20
# 51289       0.2   -0.6048           0.17
#
# [51290 rows x 3 columns]

# %%
df.order_id
# Out:
# 0           AG-2011-2040
# 1          IN-2011-47883
# 2           HU-2011-1220
# 3        IT-2011-3647632
# 4          IN-2011-47883
#               ...
# 51285     CA-2014-115427
# 51286       MO-2014-2560
# 51287     MX-2014-110527
# 51288     MX-2014-114783
# 51289     CA-2014-156720
# Name: order_id, Length: 51290, dtype: object

# %%
df['order_id'][1:5]
# Out:
# 1      IN-2011-47883
# 2       HU-2011-1220
# 3    IT-2011-3647632
# 4      IN-2011-47883
# Name: order_id, dtype: object

# %%
df['order_id'][1:40:2]
# Out:
# 1       IN-2011-47883
# 3     IT-2011-3647632
# 5       IN-2011-47883
# 7       IN-2011-79397
# 9        IZ-2011-4680
# 11      IN-2011-65159
# 13      IN-2011-33652
# 15     MX-2011-160234
# 17      ID-2011-80230
# 19      ID-2011-12596
# 21       IR-2011-7690
# 23       TZ-2011-7370
# 25      IN-2011-65159
# 27     MX-2011-111255
# 29     MX-2011-158771
# 31     MX-2011-111255
# 33     US-2011-136007
# 35     MX-2011-159373
# 37    IT-2011-2942451
# 39      IN-2011-33036
# Name: order_id, dtype: object

# %% [markdown]
# ## add columns in df

# %%
df['new_col'] = 'yuvraj'

# %%
df.head(2)
# Out:
#         order_id order_date ship_date       ship_mode    customer_name  \
# 0   AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1  IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#     segment            state    country  market   region  ... sub_category  \
# 0  Consumer      Constantine    Algeria  Africa   Africa  ...      Storage
# 1  Consumer  New South Wales  Australia    APAC  Oceania  ...     Supplies
#
#                product_name sales quantity discount   profit  shipping_cost  \
# 0       Tenex Lockers, Blue   408        2      0.0  106.140          35.46
# 1  Acme Trimmer, High Speed   120        3      0.1   36.036           9.72
#
#    order_priority  year new_col
# 0          Medium  2011  yuvraj
# 1          Medium  2011  yuvraj
#
# [2 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'new_col'],
#       dtype='object')

# %%
df['order_id'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## null data handling

# %%
df1=pd.read_csv('D:\s\iNuron\data\DressSales.csv')

# %%
df1.head()
# Out:
#      Dress_ID  29/8/2013  31/8/2013  2/9/2013  4/9/2013  6/9/2013  8/9/2013  \
# 0  1006032852       2114       2274      2491      2660      2727      2887
# 1  1212192089        151        275       570       750       813      1066
# 2  1190380701          6          7         7         7         8         8
# 3   966005983       1005       1128      1326      1455      1507      1621
# 4   876339541        996       1175      1304      1396      1432      1559
#
#    10/9/2013 12/9/2013 14/9/2013  ... Unnamed: 26 Unnamed: 27 Unnamed: 28  \
# 0       2930      3119      3204  ...         NaN         NaN         NaN
# 1       1164      1558      1756  ...         NaN         NaN         NaN
# 2          9        10        10  ...         NaN         NaN         NaN
# 3       1637      1723      1746  ...         NaN         NaN         NaN
# 4       1570      1638      1655  ...         NaN         NaN         NaN
#
# ...

# %%
df1.isnull().sum()
# Out:
# Dress_ID         0
# 29/8/2013        0
# 31/8/2013        0
# 2/9/2013         0
# 4/9/2013         0
# 6/9/2013         0
# 8/9/2013         0
# 10/9/2013        0
# 12/9/2013        0
# 14/9/2013        0
# 16/9/2013        0
# 18/9/2013        0
# 20/9/2013        0
# 22/9/2013        0
# 24/9/2013        0
# 26/9/2013      237
# 28/9/2013        0
# 30/9/2013      273
# 2/10/2013      275
# 4/10/2013      274
# 6/10/2013        0
# 8/10/2010      271
# 10/10/2013     271
# 12/10/2013       0
# Unnamed: 24    500
# Unnamed: 25    500
# Unnamed: 26    500
# Unnamed: 27    500
# Unnamed: 28    500
# Unnamed: 29    500
# Unnamed: 30    500
# Unnamed: 31    500
# Unnamed: 32    500
# Unnamed: 33    500
# Unnamed: 34    500
# Unnamed: 35    500
# dtype: int64

# %%
df1['Unnamed: 26']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 495   NaN
# 496   NaN
# 497   NaN
# 498   NaN
# 499   NaN
# Name: Unnamed: 26, Length: 500, dtype: float64

# %% [markdown]
# # who get maximum profit from df

# %%
df [['customer_name', 'profit']]
# Out:
#           customer_name    profit
# 0       Toby Braunhardt  106.1400
# 1           Joseph Holt   36.0360
# 2         Annie Thurman   29.6400
# 3          Eugene Moren  -26.0550
# 4           Joseph Holt   37.7700
# ...                 ...       ...
# 51285        Erica Bern    4.5188
# 51286         Liz Preis    0.4200
# 51287  Charlotte Melton   12.3600
# 51288     Tamara Dahlen    0.5600
# 51289     Jill Matthias   -0.6048
#
# [51290 rows x 2 columns]

# %%
df['profit'] == max(df['profit'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Name: profit, Length: 51290, dtype: bool

# %%
df[df['profit'] == max(df['profit'])]
# Out:
#              order_id order_date   ship_date       ship_mode customer_name  \
# 29530  CA-2013-118689  10/3/2013  10/10/2013  Standard Class  Tamara Chand
#
#          segment    state        country market   region  ... sub_category  \
# 29530  Corporate  Indiana  United States     US  Central  ...      Copiers
#
#                                 product_name   sales quantity discount  \
# 29530  Canon imageCLASS 2200 Advanced Copier  17,500        5      0.0
#
#          profit  shipping_cost  order_priority  year new_col
# 29530  8399.976         349.07          Medium  2013  yuvraj
#
# [1 rows x 22 columns]

# %% [markdown]
# ## get the all data belongs to Sweden only

# %%
df[df['country'] == 'Sweden']
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 3      IT-2011-3647632    1/1/2011    1/5/2011    Second Class
# 168    IT-2011-5951216   1/13/2011   1/20/2011  Standard Class
# 477    IT-2011-5645183    2/3/2011    2/5/2011    Second Class
# 1342   IT-2011-5233011   3/31/2011    4/6/2011  Standard Class
# 1554   IT-2011-2419493   4/12/2011   4/13/2011     First Class
# ...                ...         ...         ...             ...
# 50948  IT-2014-5217096  12/26/2014  12/31/2014  Standard Class
# 50949  IT-2014-5217096  12/26/2014  12/31/2014  Standard Class
# 50972  IT-2014-4046179  12/27/2014  12/30/2014    Second Class
# 51086  IT-2014-2362249  12/29/2014    1/1/2015     First Class
# 51121  IT-2014-2362249  12/29/2014    1/1/2015     First Class
#
#          customer_name      segment            state country market region  \
# 3         Eugene Moren  Home Office        Stockholm  Sweden     EU  North
# ...

# %% [markdown]
# ## how many orders from Sweden

# %%
len(df[df['country'] == 'Sweden'])
# Out:
# 203

# %%
df[df['shipping_cost'] >20]
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011    1/6/2011  Standard Class
# 6         CA-2011-1510    1/2/2011    1/6/2011  Standard Class
# 7        IN-2011-79397    1/3/2011    1/3/2011        Same Day
# 8        ID-2011-80230    1/3/2011    1/9/2011  Standard Class
# 9         IZ-2011-4680    1/3/2011    1/7/2011  Standard Class
# ...                ...         ...         ...             ...
# 51241  ES-2014-3638865  12/31/2014    1/1/2015     First Class
# 51242   MX-2014-141712  12/31/2014  12/31/2014        Same Day
# 51243    IN-2014-78627  12/31/2014    1/4/2015  Standard Class
# 51244  IT-2014-3715679  12/31/2014    1/5/2015    Second Class
# 51245    IN-2014-75603  12/31/2014    1/5/2015    Second Class
#
#           customer_name      segment            state         country  market  \
# 0       Toby Braunhardt     Consumer      Constantine         Algeria  Africa
# ...

# %%
df[df['shipping_cost'] >80]
# Out:
#              order_id  order_date ship_date       ship_mode  \
# 7       IN-2011-79397    1/3/2011  1/3/2011        Same Day
# 8       ID-2011-80230    1/3/2011  1/9/2011  Standard Class
# 9        IZ-2011-4680    1/3/2011  1/7/2011  Standard Class
# 27     MX-2011-111255    1/4/2011  1/9/2011    Second Class
# 43     MX-2011-109267    1/5/2011  1/9/2011  Standard Class
# ...               ...         ...       ...             ...
# 51154   IN-2014-49206  12/30/2014  1/1/2015    Second Class
# 51228  MX-2014-116267  12/31/2014  1/3/2015    Second Class
# 51229   IN-2014-43550  12/31/2014  1/1/2015     First Class
# 51230    RS-2014-1460  12/31/2014  1/2/2015    Second Class
# 51231   IN-2014-30390  12/31/2014  1/3/2015     First Class
#
#              customer_name    segment            state      country market  \
# 7              Kean Nguyen  Corporate  New South Wales    Australia   APAC
# 8             Ken Lonsdale   Consumer         Auckland  New Zealand   APAC
# ...

# %%
df[df['shipping_cost'] >80]['country']
# Out:
# 7          Australia
# 8        New Zealand
# 9               Iraq
# 27            Brazil
# 43            Mexico
#             ...
# 51154      Indonesia
# 51228         Brazil
# 51229      Indonesia
# 51230         Russia
# 51231       Thailand
# Name: country, Length: 3984, dtype: object

# %%
df[(df['shipping_cost'] >100) & (df['profit'] <10)]
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 8        ID-2011-80230    1/3/2011    1/9/2011  Standard Class
# 257     MX-2011-146584   1/21/2011   1/27/2011  Standard Class
# 451    ES-2011-1640672    2/2/2011    2/5/2011     First Class
# 625      ID-2011-47575   2/15/2011   2/21/2011  Standard Class
# 626      ID-2011-47575   2/15/2011   2/21/2011  Standard Class
# ...                ...         ...         ...             ...
# 50781   CA-2014-147956  12/25/2014    1/1/2015  Standard Class
# 50969   US-2014-120166  12/27/2014  12/31/2014  Standard Class
# 50970  ES-2014-4296634  12/27/2014    1/2/2015  Standard Class
# 51034    ID-2014-68183  12/29/2014  12/31/2014     First Class
# 51153    ID-2014-51509  12/30/2014    1/1/2015    Second Class
#
#               customer_name    segment                         state  \
# 8              Ken Lonsdale   Consumer                      Auckland
# ...

# %%
df[(df['shipping_cost'] >100) & (df['profit'] <10)]['country']
# Out:
# 8          New Zealand
# 257          Nicaragua
# 451            Germany
# 625        Philippines
# 626        Philippines
#              ...
# 50781    United States
# 50969         Colombia
# 50970           France
# 51034        Australia
# 51153        Australia
# Name: country, Length: 604, dtype: object

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# new_col            object
# dtype: object

# %% [markdown]
# ## work with DATE data

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# new_col            object
# dtype: object

# %%
date=pd.to_datetime(df['order_date'])

# %%
df['coverted_date'] =pd.to_datetime(df['order_date'])

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df['order_date_year']= df['coverted_date'].dt.year

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df['order_date_month']= df['coverted_date'].dt.month

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df['order_date_week']= df['coverted_date'].dt.week
# Out:
# C:\Users\Yuvraj\AppData\Local\Temp\ipykernel_8048\2718258380.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['order_date_week']= df['coverted_date'].dt.week

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df[['coverted_date', 'order_date_week']]
# Out:
#       coverted_date  order_date_week
# 0        2011-01-01               52
# 1        2011-01-01               52
# 2        2011-01-01               52
# 3        2011-01-01               52
# 4        2011-01-01               52
# ...             ...              ...
# 51285    2014-12-31                1
# 51286    2014-12-31                1
# 51287    2014-12-31                1
# 51288    2014-12-31                1
# 51289    2014-12-31                1
#
# [51290 rows x 2 columns]

# %%
df[df['order_date_year'] == 2014]
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 33759  ES-2014-2774938    1/1/2014  1/3/2014    Second Class
# 33760    IN-2014-47134    1/1/2014  1/5/2014  Standard Class
# 33761  IT-2014-4810734    1/1/2014  1/3/2014    Second Class
# 33762   US-2014-105830    1/1/2014  1/3/2014     First Class
# 33763   CA-2014-160395    1/1/2014  1/7/2014  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name    segment             state        country  market  \
# 33759       Fred Harton   Consumer     Ile-de-France         France      EU
# 33760       Kean Nguyen  Corporate          Victoria      Australia    APAC
# ...

# %%
df['order_date_month'].value_counts()
# Out:
# 11    6342
# 12    6302
# 9     5975
# 6     5331
# 8     5078
# 10    4490
# 5     3747
# 7     3166
# 4     3057
# 3     3035
# 1     2599
# 2     2168
# Name: order_date_month, dtype: int64

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... discount  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...      0.0
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...      0.0
# 3  Home Office        Stockholm     Sweden      EU    North  ...      0.5
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
#
#     profit shipping_cost order_priority  year  new_col  coverted_date  \
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'new_col', 'coverted_date', 'order_date_year', 'order_date_month',
#        'order_date_week'],
#       dtype='object')

# %%
df['cost_to_company'] = df['discount']+df['shipping_cost']

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df[df['cost_to_company'] == max(df['cost_to_company'])]
# Out:
#              order_id order_date  ship_date ship_mode customer_name   segment  \
# 13891  CA-2012-124891  7/31/2012  7/31/2012  Same Day   Rick Hansen  Consumer
#
#           state        country market region  ...    profit shipping_cost  \
# 13891  New York  United States     US   East  ...  762.1845        933.57
#
#       order_priority  year new_col  coverted_date  order_date_year  \
# 13891       Critical  2012  yuvraj     2012-07-31             2012
#
#        order_date_month  order_date_week cost_to_company
# 13891                 7               31          933.57
#
# [1 rows x 27 columns]

# %%
df[df['cost_to_company'] == max(df['cost_to_company'])]['product_name']
# Out:
# 13891    Plantronics CS510 - Over-the-Head monaural Wir...
# Name: product_name, dtype: object

# %% [markdown]
# ## delete columns

# %%
df.drop('cost_to_company',axis=1)
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.drop('cost_to_company',axis=1,inplace=True)

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.drop(1, inplace=True) # row deleted

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %% [markdown]
# ## filter out by row's

# %% [raw]
# 1 loc  #loc always take name wise
# 2 iloc
# 3 ?

# %%
df.loc[[2,3]] #loc is location
# Out:
#           order_id order_date ship_date     ship_mode  customer_name  \
# 2     HU-2011-1220   1/1/2011  1/5/2011  Second Class  Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011  Second Class   Eugene Moren
#
#        segment      state  country market region  ... discount  profit  \
# 2     Consumer   Budapest  Hungary   EMEA   EMEA  ...      0.0  29.640
# 3  Home Office  Stockholm   Sweden     EU  North  ...      0.5 -26.055
#
#   shipping_cost order_priority  year  new_col  coverted_date  order_date_year  \
# 2          8.17           High  2011   yuvraj     2011-01-01             2011
# 3          4.82           High  2011   yuvraj     2011-01-01             2011
#
#    order_date_month order_date_week
# 2                 1              52
# 3                 1              52
#
# [2 rows x 26 columns]

# %%
df.loc[[2:11]] # : consider as range
# Out:
#          order_id order_date ship_date     ship_mode  customer_name   segment  \
# 2    HU-2011-1220   1/1/2011  1/5/2011  Second Class  Annie Thurman  Consumer
# 11  IN-2011-65159   1/3/2011  1/7/2011  Second Class   Larry Blacks  Consumer
#
#                state      country market          region  ... discount  \
# 2           Budapest      Hungary   EMEA            EMEA  ...     0.00
# 11  National Capital  Philippines   APAC  Southeast Asia  ...     0.55
#
#      profit shipping_cost order_priority  year  new_col  coverted_date  \
# 2   29.6400          8.17           High  2011   yuvraj     2011-01-01
# 11 -70.3995         21.32           High  2011   yuvraj     2011-01-03
#
#     order_date_year  order_date_month order_date_week
# 2              2011                 1              52
# 11             2011                 1               1
#
# [2 rows x 26 columns]

# %%
df.loc[2:20:2]
# Out:
#            order_id order_date ship_date       ship_mode      customer_name  \
# 2      HU-2011-1220   1/1/2011  1/5/2011    Second Class      Annie Thurman
# 4     IN-2011-47883   1/1/2011  1/8/2011  Standard Class        Joseph Holt
# 6      CA-2011-1510   1/2/2011  1/6/2011  Standard Class    Magdelene Morse
# 8     ID-2011-80230   1/3/2011  1/9/2011  Standard Class       Ken Lonsdale
# 10    IN-2011-65159   1/3/2011  1/7/2011    Second Class       Larry Blacks
# 12  ES-2011-4869686   1/3/2011  1/7/2011  Standard Class  Dorothy Dickinson
# 14    ID-2011-80230   1/3/2011  1/9/2011  Standard Class       Ken Lonsdale
# 16      IR-2011-770   1/3/2011  1/7/2011  Standard Class      Jas O'Carroll
# 18    ID-2011-80230   1/3/2011  1/9/2011  Standard Class       Ken Lonsdale
# 20    IN-2011-79397   1/3/2011  1/3/2011        Same Day        Kean Nguyen
#
#       segment             state         country  market          region  ...  \
# ...

# %%
df.loc[0:4,['order_id','order_date']]
# Out:
#           order_id order_date
# 0     AG-2011-2040   1/1/2011
# 2     HU-2011-1220   1/1/2011
# 3  IT-2011-3647632   1/1/2011
# 4    IN-2011-47883   1/1/2011

# %%
df.iloc[0:4,0:7:2]# iloc always take defaul indexes
# Out:
#           order_id ship_date    customer_name            state
# 0     AG-2011-2040  1/6/2011  Toby Braunhardt      Constantine
# 2     HU-2011-1220  1/5/2011    Annie Thurman         Budapest
# 3  IT-2011-3647632  1/5/2011     Eugene Moren        Stockholm
# 4    IN-2011-47883  1/8/2011      Joseph Holt  New South Wales

# %%
df.iloc[1:5,3:6]
# Out:
#         ship_mode  customer_name      segment
# 2    Second Class  Annie Thurman     Consumer
# 3    Second Class   Eugene Moren  Home Office
# 4  Standard Class    Joseph Holt     Consumer
# 5  Standard Class    Joseph Holt     Consumer

# %%
num_data=df[df.dtypes[(df.dtypes == 'float64') | (df.dtypes == 'int64')].index]

# %%
df3=num_data[num_data >100]

# %%
df3.dropna()
# Out:
# Empty DataFrame
# Columns: [quantity, discount, profit, shipping_cost, year, order_date_year, order_date_month, order_date_week]
# Index: []

# %%
df3.dropna(thresh=3)
# Out:
#        quantity  discount   profit  shipping_cost  year  order_date_year  \
# 0           NaN       NaN  106.140            NaN  2011             2011
# 7           NaN       NaN  110.412         125.32  2011             2011
# 8           NaN       NaN      NaN         107.10  2011             2011
# 9           NaN       NaN  253.320            NaN  2011             2011
# 12          NaN       NaN  290.430            NaN  2011             2011
# ...         ...       ...      ...            ...   ...              ...
# 51234       NaN       NaN  216.720            NaN  2014             2014
# 51236       NaN       NaN  180.240            NaN  2014             2014
# 51245       NaN       NaN  105.000            NaN  2014             2014
# 51252       NaN       NaN  166.440            NaN  2014             2014
# 51269       NaN       NaN  153.090            NaN  2014             2014
#
#        order_date_month  order_date_week
# 0                   NaN              NaN
# ...

# %%
df3_dummy=df3.fillna(value=3)
df3_dummy
# Out:
#        quantity  discount  profit  shipping_cost  year  order_date_year  \
# 0           3.0       3.0  106.14            3.0  2011             2011
# 2           3.0       3.0    3.00            3.0  2011             2011
# 3           3.0       3.0    3.00            3.0  2011             2011
# 4           3.0       3.0    3.00            3.0  2011             2011
# 5           3.0       3.0    3.00            3.0  2011             2011
# ...         ...       ...     ...            ...   ...              ...
# 51285       3.0       3.0    3.00            3.0  2014             2014
# 51286       3.0       3.0    3.00            3.0  2014             2014
# 51287       3.0       3.0    3.00            3.0  2014             2014
# 51288       3.0       3.0    3.00            3.0  2014             2014
# 51289       3.0       3.0    3.00            3.0  2014             2014
#
#        order_date_month  order_date_week
# 0                   3.0              3.0
# ...

# %%
df3_fill_mean= df3.fillna(value=df3['profit'].mean())

# %%
df3_fill_mean
# Out:
#          quantity    discount      profit  shipping_cost  year  \
# 0      285.710477  285.710477  106.140000     285.710477  2011
# 2      285.710477  285.710477  285.710477     285.710477  2011
# 3      285.710477  285.710477  285.710477     285.710477  2011
# 4      285.710477  285.710477  285.710477     285.710477  2011
# 5      285.710477  285.710477  285.710477     285.710477  2011
# ...           ...         ...         ...            ...   ...
# 51285  285.710477  285.710477  285.710477     285.710477  2014
# 51286  285.710477  285.710477  285.710477     285.710477  2014
# 51287  285.710477  285.710477  285.710477     285.710477  2014
# 51288  285.710477  285.710477  285.710477     285.710477  2014
# 51289  285.710477  285.710477  285.710477     285.710477  2014
#
#        order_date_year  order_date_month  order_date_week
# 0                 2011        285.710477       285.710477
# 2                 2011        285.710477       285.710477
# ...

# %% [markdown]
# # yearly average profit

# %%
df.groupby('order_date_year')['profit'].mean()
# Out:
# order_date_year
# 2011    27.665308
# 2012    28.043722
# 2013    29.604519
# 2014    28.758540
# Name: profit, dtype: float64

# %%
df.groupby('order_date_year')['discount'].mean()
# Out:
# order_date_year
# 2011    0.148193
# 2012    0.141286
# 2013    0.140265
# 2014    0.143291
# Name: discount, dtype: float64

# %%
df.groupby('order_date_year')['shipping_cost'].mean()
# Out:
# order_date_year
# 2011    27.149201
# 2012    25.861329
# 2013    26.418577
# 2014    26.268197
# Name: shipping_cost, dtype: float64

# %%
df[['country','market']]
# Out:
#              country  market
# 0            Algeria  Africa
# 2            Hungary    EMEA
# 3             Sweden      EU
# 4          Australia    APAC
# 5          Australia    APAC
# ...              ...     ...
# 51285  United States      US
# 51286        Morocco  Africa
# 51287      Nicaragua   LATAM
# 51288         Mexico   LATAM
# 51289  United States      US
#
# [51289 rows x 2 columns]

# %%
df.groupby('order_date_year')['shipping_cost'].mean()
# Out:
# order_date_year
# 2011    27.149201
# 2012    25.861329
# 2013    26.418577
# 2014    26.268197
# Name: shipping_cost, dtype: float64

# %%
df['sales'] = df.sales.str.replace(',','').astype(int)

# %%
df.dtypes
# Out:
# order_id                    object
# order_date                  object
# ship_date                   object
# ship_mode                   object
# customer_name               object
# segment                     object
# state                       object
# country                     object
# market                      object
# region                      object
# product_id                  object
# category                    object
# sub_category                object
# product_name                object
# sales                        int32
# quantity                     int64
# discount                   float64
# profit                     float64
# shipping_cost              float64
# order_priority              object
# year                         int64
# new_col                     object
# coverted_date       datetime64[ns]
# order_date_year              int64
# order_date_month             int64
# order_date_week              int64
# dtype: object

# %%
df.groupby('order_date_year')['sales'].mean()
# Out:
# order_date_year
# 2011    251.127153
# 2012    244.252235
# 2013    246.819335
# 2014    245.282129
# Name: sales, dtype: float64

# %%
df.groupby('order_date_year')['quantity'].mean()
# Out:
# order_date_year
# 2011    3.494498
# 2012    3.476647
# 2013    3.488369
# 2014    3.457989
# Name: quantity, dtype: float64

# %%
df.groupby('order_date_month')['sales'].mean()
# Out:
# order_date_month
# 1     259.823326
# 2     250.815498
# 3     253.877759
# 4     228.525679
# 5     241.275954
# 6     238.182517
# 7     236.709728
# 8     254.795589
# 9     240.574393
# 10    260.182628
# 11    244.610375
# 12    250.843542
# Name: sales, dtype: float64

# %%
df.groupby('order_date_week')['sales'].mean()
# Out:
# order_date_week
# 1     248.038074
# 2     271.523560
# 3     253.222597
# 4     250.572402
# 5     264.147874
# 6     261.346516
# 7     245.376289
# 8     239.408015
# 9     249.382609
# 10    226.200000
# 11    279.086580
# 12    239.919060
# 13    269.141194
# 14    229.175036
# 15    224.455696
# 16    242.575558
# 17    213.523055
# 18    229.360274
# 19    220.679739
# 20    226.459900
# 21    254.652120
# 22    265.364004
# 23    236.670886
# 24    235.485340
# 25    244.087789
# 26    245.125920
# 27    232.142487
# 28    229.069482
# 29    236.259151
# 30    246.590164
# 31    249.547744
# 32    244.249771
# 33    251.565911
# 34    260.513784
# 35    254.694470
# 36    242.784384
# 37    235.470333
# 38    269.639024
# 39    215.992324
# 40    273.158092
# 41    260.310419
# 42    269.631107
# 43    254.180080
# 44    248.551020
# 45    247.171508
# 46    239.868146
# 47    233.288732
# 48    254.743680
# 49    238.676164
# 50    243.893983
# 51    264.620739
# ...
